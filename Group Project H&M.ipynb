# %%
import psycopg2

# %%
conn = psycopg2.connect(
   host="localhost",
   database="Group Project",
   user="postgres",
   password="123")
  
print("Database connected successfully")
# Out:
# Database connected successfully

# %%
cur = conn.cursor()

# %%
import pandas as pd

# %%
#read data 
product = pd.read_csv(r'/Users/minahsu/Desktop/Columbia Work/Spring 2022/SQL/Group Project/tables/Python/product.csv')
product
# Out:
#                     prod_name  product_type_no product_type_name  \
# 0                   Strap top              253          Vest top
# 1               Strap top (1)              253          Vest top
# 2           OP T-shirt (Idro)              306               Bra
# 3         20 den 1p Stockings              304  Underwear Tights
# 4         20 den 1p Stockings              302             Socks
# ...                       ...              ...               ...
# 46787  5pk regular Placement1              302             Socks
# 46788       SPORT Malaga tank              253          Vest top
# 46789         Cartwheel dress              265             Dress
# 46790        CLAIRE HAIR CLAW               72         Hair clip
# 46791            Lounge dress              265             Dress
#
#        product_group_name  product_id
# 0      Garment Upper body    10000001
# 1      Garment Upper body    10000002
# 2               Underwear    10000003
# ...

# %%
product= product.loc[:, ['product_id','prod_name','product_type_no', 'product_type_name', 'product_group_name']]
product = product.drop_duplicates()
product= pd.DataFrame(product)
product
# Out:
#        product_id               prod_name  product_type_no product_type_name  \
# 0        10000001               Strap top              253          Vest top
# 1        10000002           Strap top (1)              253          Vest top
# 2        10000003       OP T-shirt (Idro)              306               Bra
# 3        10000004     20 den 1p Stockings              304  Underwear Tights
# 4        10000005     20 den 1p Stockings              302             Socks
# ...           ...                     ...              ...               ...
# 46787    10046788  5pk regular Placement1              302             Socks
# 46788    10046789       SPORT Malaga tank              253          Vest top
# 46789    10046790         Cartwheel dress              265             Dress
# 46790    10046791        CLAIRE HAIR CLAW               72         Hair clip
# 46791    10046792            Lounge dress              265             Dress
#
#        product_group_name
# ...

# %%
department = pd.read_csv(r'/Users/minahsu/Desktop/Columbia Work/Spring 2022/SQL/Group Project/tables/Python/department.csv')
department = department.loc[:, ['department_id','department_name']]
department = department.drop_duplicates()
department= pd.DataFrame(department)
department
# Out:
#      department_id            department_name
# 0         31000001               Jersey Basic
# 1         31000002             Clean Lingerie
# 2         31000003               Tights basic
# 3         31000004                Baby basics
# 4         31000005            Casual Lingerie
# ..             ...                        ...
# 294       31000295  Baby Girl Local Relevance
# 295       31000296            EQ Divided Blue
# 296       31000297         Kids Boy Exclusive
# 297       31000298          Accessories Other
# 298       31000299                     Blanks
#
# [299 rows x 2 columns]

# %%
graphical_appearance = pd.read_csv(r'/Users/minahsu/Desktop/Columbia Work/Spring 2022/SQL/Group Project/tables/Python/graphical.csv')
graphical_appearance = graphical_appearance.loc[:, ['graphical_id','graphical_appearance_name']]
graphical_appearance = graphical_appearance.drop_duplicates()
graphical_appearance = pd.DataFrame(graphical_appearance)
graphical_appearance
# Out:
#     graphical_id graphical_appearance_name
# 0       20000001                     Solid
# 1       20000002                    Stripe
# 2       20000003          All over pattern
# 3       20000004                   Melange
# 4       20000005               Transparent
# 5       20000006                  Metallic
# 6       20000007            Application/3D
# 7       20000008                     Denim
# 8       20000009           Colour blocking
# 9       20000010                       Dot
# 10      20000011           Other structure
# 11      20000012                  Contrast
# 12      20000013                 Treatment
# 13      20000014                     Check
# 14      20000015                  Chambray
# 15      20000016               Front print
# 16      20000017       Glittering/Metallic
# 17      20000018       Mixed solid/pattern
# 18      20000019           Placement print
# 19      20000020             Other pattern
# 20      20000021                      Neps
# ...

# %%
color = pd.read_csv(r'/Users/minahsu/Desktop/Columbia Work/Spring 2022/SQL/Group Project/tables/Python/colour.csv')
color = color.loc[:, ["colour_id",
                        "colour_group_code",
                        "colour_group_name",
                        "perceived_colour_master_id",
                        "perceived_colour_master_name"]]
color = color.drop_duplicates()
color = pd.DataFrame(color)
color
# Out:
#      colour_id  colour_group_code colour_group_name  \
# 0     41000001                  9             Black
# 1     41000002                 10             White
# 2     41000003                 11         Off White
# 3     41000004                 12       Light Beige
# 4     41000005                 13             Beige
# ..         ...                ...               ...
# 291   41000292                 72              Blue
# 292   41000293                 63       Dark Purple
# 293   41000294                  7              Grey
# 294   41000295                 63       Dark Purple
# 295   41000296                 19    Greenish Khaki
#
#      perceived_colour_master_id perceived_colour_master_name
# 0                             5                        Black
# 1                             9                        White
# 2                             9                        White
# 3                            11                        Beige
# ...

# %%
color = color.rename(columns={"colour_id": "color_id", "colour_group_code" : "color_group_code",
                              "colour_group_name":"color_group_name",
                              "perceived_colour_master_id" : "perceived_color_master_id",
                              "perceived_colour_master_name" : "perceived_color_master_name" })
color
# Out:
#      color_id  color_group_code color_group_name  perceived_color_master_id  \
# 0    41000001                 9            Black                          5
# 1    41000002                10            White                          9
# 2    41000003                11        Off White                          9
# 3    41000004                12      Light Beige                         11
# 4    41000005                13            Beige                         11
# ..        ...               ...              ...                        ...
# 291  41000292                72             Blue                          6
# 292  41000293                63      Dark Purple                          2
# 293  41000294                 7             Grey                         -1
# 294  41000295                63      Dark Purple                         18
# 295  41000296                19   Greenish Khaki                         11
#
#     perceived_color_master_name
# ...

# %%
section = pd.read_csv(r'/Users/minahsu/Desktop/Columbia Work/Spring 2022/SQL/Group Project/tables/Python/section.csv')
section = section.loc[:, ["section_id",
                          "section_name",
                        "garment_group_no",
                        "garment_group_name"]]
section = section.drop_duplicates()
section = pd.DataFrame(section)
section
# Out:
#      section_id                    section_name  garment_group_no  \
# 0      60000001          Womens Everyday Basics              1002
# 1      60000002                 Womens Lingerie              1017
# 2      60000003  Womens Nightwear, Socks & Tigh              1021
# 3      60000004   Baby Essentials & Complements              1002
# 4      60000005                   Men Underwear              1002
# ..          ...                             ...               ...
# 190    60000191       Divided Complements Other              1016
# 191    60000192                       Kids Girl              1023
# 192    60000193             Contemporary Street              1001
# 193    60000194                        Kids Boy              1001
# 194    60000195       Divided Complements Other              1019
#
#     garment_group_name
# 0         Jersey Basic
# 1    Under-, Nightwear
# 2     Socks and Tights
# 3         Jersey Basic
# 4         Jersey Basic
# ..                 ...
# ...

# %%
index = pd.read_csv(r'/Users/minahsu/Desktop/Columbia Work/Spring 2022/SQL/Group Project/tables/Python/index.csv')
index = index.loc[:, ['index_id', 'index_name', 'index_group_no', 'index_group_name']]
index = index.drop_duplicates()
index = pd.DataFrame(index)
index
# Out:
#    index_id                      index_name  index_group_no index_group_name
# 0  50000001                      Ladieswear               1       Ladieswear
# 1  50000002                Lingeries/Tights               1       Ladieswear
# 2  50000003                Baby Sizes 50-98               4    Baby/Children
# 3  50000004                        Menswear               3         Menswear
# 4  50000005              Ladies Accessories               1       Ladieswear
# 5  50000006                           Sport              26            Sport
# 6  50000007           Children Sizes 92-140               4    Baby/Children
# 7  50000008                         Divided               2          Divided
# 8  50000009          Children Sizes 134-170               4    Baby/Children
# 9  50000010  Children Accessories, Swimwear               4    Baby/Children

# %%
index = index.rename(columns={"index_group_no": "index_group_id"})
index
# Out:
#    index_id                      index_name  index_group_id index_group_name
# 0  50000001                      Ladieswear               1       Ladieswear
# 1  50000002                Lingeries/Tights               1       Ladieswear
# 2  50000003                Baby Sizes 50-98               4    Baby/Children
# 3  50000004                        Menswear               3         Menswear
# 4  50000005              Ladies Accessories               1       Ladieswear
# 5  50000006                           Sport              26            Sport
# 6  50000007           Children Sizes 92-140               4    Baby/Children
# 7  50000008                         Divided               2          Divided
# 8  50000009          Children Sizes 134-170               4    Baby/Children
# 9  50000010  Children Accessories, Swimwear               4    Baby/Children

# %%
fashion_news = pd.read_csv(r'/Users/minahsu/Desktop/Columbia Work/Spring 2022/SQL/Group Project/tables/Python/fashion_news.csv')
fashion_news = fashion_news.loc[:, ["FN",
                        "fashion_news_frequency",
                                   "Active"]]
fashion_news = fashion_news.drop_duplicates()
fashion_news
# Out:
#           FN fashion_news_frequency  Active
# 0      False                   NONE   False
# 4       True              Regularly    True
# 5      False                    NaN   False
# 137     True              Regularly   False
# 248    False              Regularly   False
# 335     True                   NONE   False
# 4744    True                   NONE    True
# 5040    True                Monthly    True
# 28322  False                Monthly   False
# 77529   True                Monthly   False

# %%
fashion_news.insert(0, 'fn_id', range(900000000, 900000000 + len(fashion_news)))
fashion_news = pd.DataFrame(fashion_news)
fashion_news
# Out:
#            fn_id     FN fashion_news_frequency  Active
# 0      900000000  False                   NONE   False
# 4      900000001   True              Regularly    True
# 5      900000002  False                    NaN   False
# 137    900000003   True              Regularly   False
# 248    900000004  False              Regularly   False
# 335    900000005   True                   NONE   False
# 4744   900000006   True                   NONE    True
# 5040   900000007   True                Monthly    True
# 28322  900000008  False                Monthly   False
# 77529  900000009   True                Monthly   False

# %%
fashion_news = fashion_news.rename(columns={"FN": "fn", "FN_id" : "fn_id", "Active":"active"})
fashion_news
# Out:
#            fn_id     fn fashion_news_frequency  active
# 0      900000000  False                   NONE   False
# 4      900000001   True              Regularly    True
# 5      900000002  False                    NaN   False
# 137    900000003   True              Regularly   False
# 248    900000004  False              Regularly   False
# 335    900000005   True                   NONE   False
# 4744   900000006   True                   NONE    True
# 5040   900000007   True                Monthly    True
# 28322  900000008  False                Monthly   False
# 77529  900000009   True                Monthly   False

# %%
customer_info = pd.read_csv(r'/Users/minahsu/Desktop/Columbia Work/Spring 2022/SQL/Group Project/tables/customers.csv')
customer_info = customer_info.loc[:, ["customer_id",
                        "age",
                        "club_member_status"]]
customer_info = customer_info.drop_duplicates()
customer_info = pd.DataFrame(customer_info)
customer_info
# Out:
#                                               customer_id   age  \
# 0       00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...  49.0
# 1       0000423b00ade91418cceaf3b26c6af3dd342b51fd051e...  25.0
# 2       000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...  24.0
# 3       00005ca1c9ed5f5146b52ac8639a40ca9d57aeff4d1bd2...  54.0
# 4       00006413d8573cd20ed7128e53b7b13819fe5cfc2d801f...  52.0
# ...                                                   ...   ...
# 404434  4b9e8490036f8b6631c298802064fccd6c4ff41a5f755f...  21.0
# 404435  4b9eaaf9fc95c429580be86f3b51e8c603907927223823...  34.0
# 404436  4b9eae5f9fc8ebb4cdf45d0af977594dba73d7b97be909...  55.0
# 404437  4b9eb6a6ba2776d99ae241366b13b89a3bb0cbef20f0bc...  58.0
# 404438  4b9ec29639850ce7ec57ca9875cfc5a9d14f92a2c5f313...  22.0
#
#        club_member_status
# 0                  ACTIVE
# 1                  ACTIVE
# 2                  ACTIVE
# 3                  ACTIVE
# 4                  ACTIVE
# ...                   ...
# ...

# %%
trans = pd.read_csv(r'/Users/minahsu/Desktop/Columbia Work/Spring 2022/SQL/Group Project/tables/Python/trans.csv')
trans = trans.loc[:, ["t_dat",
                        "customer_id",
                        "article_id",
                        "price",
                        "sales_channel_id"]]
trans = trans.drop_duplicates()
trans = pd.DataFrame(trans)
trans
# Out:
#              t_dat                                        customer_id  \
# 0       2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...
# 6       2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...
# 12      2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...
# 18      2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...
# 24      2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...
# ...            ...                                                ...
# 529770  2018-09-21  d54b955cbbfce16c1a685add2561ff73fadde0741eab11...
# 529776  2018-09-21  d54b955cbbfce16c1a685add2561ff73fadde0741eab11...
# 529782  2018-09-21  d54b955cbbfce16c1a685add2561ff73fadde0741eab11...
# 529794  2018-09-21  d54b955cbbfce16c1a685add2561ff73fadde0741eab11...
# 529800  2018-09-21  d54d5e6eb2070d5730c26fc7806c88e96499b5719e9a57...
#
#         article_id     price  sales_channel_id
# 0        663713001  0.050831                 2
# ...

# %%
# Reading data 
article = pd.read_csv(r'/Users/minahsu/Desktop/Columbia Work/Spring 2022/SQL/Group Project/tables/Python/articlebridge.csv')

article
# Out:
#         article_id  colour_id  department_id  graphical_id  index_id  \
# 0        108775015   41000001       31000001      20000001  50000001
# 1        108775015   41000001       31000006      20000001  50000001
# 2        108775044   41000002       31000001      20000001  50000001
# 3        108775044   41000002       31000006      20000001  50000001
# 4        108775051   41000003       31000001      20000002  50000001
# ...            ...        ...            ...           ...       ...
# 245042   959461001   41000003       31000007      20000001  50000001
# 245043   959461001   41000003       31000063      20000001  50000001
# 245044   959461001   41000003       31000099      20000001  50000001
# 245045   959461001   41000003       31000127      20000001  50000001
# 245046   959461001   41000003       31000179      20000001  50000001
#
#         product_id  section_id
# 0         10000001    60000001
# 1         10000001    60000001
# 2         10000001    60000001
# ...

# %%
article = article.loc[:, ["article_id",
                           "product_id",
                           "department_id",
                           "graphical_id",
                           "colour_id",
                           "section_id",
                            "index_id"]]
article = article.drop_duplicates()
article = pd.DataFrame(article)
article
# Out:
#         article_id  product_id  department_id  graphical_id  colour_id  \
# 0        108775015    10000001       31000001      20000001   41000001
# 1        108775015    10000001       31000006      20000001   41000001
# 2        108775044    10000001       31000001      20000001   41000002
# 3        108775044    10000001       31000006      20000001   41000002
# 4        108775051    10000002       31000001      20000002   41000003
# ...            ...         ...            ...           ...        ...
# 245042   959461001    10050044       31000007      20000001   41000003
# 245043   959461001    10050044       31000063      20000001   41000003
# 245044   959461001    10050044       31000099      20000001   41000003
# 245045   959461001    10050044       31000127      20000001   41000003
# 245046   959461001    10050044       31000179      20000001   41000003
#
#         section_id  index_id
# 0         60000001  50000001
# 1         60000001  50000001
# ...

# %%
article.insert(0, 'article_bridge_id', range(440000000, 440000000 + len(article)))
article
# Out:
#         article_bridge_id  article_id  product_id  department_id  \
# 0               440000000   108775015    10000001       31000001
# 1               440000001   108775015    10000001       31000006
# 2               440000002   108775044    10000001       31000001
# 3               440000003   108775044    10000001       31000006
# 4               440000004   108775051    10000002       31000001
# ...                   ...         ...         ...            ...
# 245042          440245042   959461001    10050044       31000007
# 245043          440245043   959461001    10050044       31000063
# 245044          440245044   959461001    10050044       31000099
# 245045          440245045   959461001    10050044       31000127
# 245046          440245046   959461001    10050044       31000179
#
#         graphical_id  colour_id  section_id  index_id
# 0           20000001   41000001    60000001  50000001
# 1           20000001   41000001    60000001  50000001
# ...

# %%
article = article.rename(columns={"colour_id": "color_id"})
article
# Out:
#         article_bridge_id  article_id  product_id  department_id  \
# 0               440000000   108775015    10000001       31000001
# 1               440000001   108775015    10000001       31000006
# 2               440000002   108775044    10000001       31000001
# 3               440000003   108775044    10000001       31000006
# 4               440000004   108775051    10000002       31000001
# ...                   ...         ...         ...            ...
# 245042          440245042   959461001    10050044       31000007
# 245043          440245043   959461001    10050044       31000063
# 245044          440245044   959461001    10050044       31000099
# 245045          440245045   959461001    10050044       31000127
# 245046          440245046   959461001    10050044       31000179
#
#         graphical_id  color_id  section_id  index_id
# 0           20000001  41000001    60000001  50000001
# 1           20000001  41000001    60000001  50000001
# ...

# %%
customer_bridge = pd.read_csv(r'/Users/minahsu/Desktop/Columbia Work/Spring 2022/SQL/Group Project/tables/Python/customer_bridge_new.csv')
customer_bridge = customer_bridge.drop_duplicates()
customer_bridge = pd.DataFrame(customer_bridge)
customer_bridge
# Out:
#                                               customer_id  fashion_news_id
# 0       00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...         91000001
# 1       0000423b00ade91418cceaf3b26c6af3dd342b51fd051e...         91000001
# 2       000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...         91000001
# 3       00005ca1c9ed5f5146b52ac8639a40ca9d57aeff4d1bd2...         91000001
# 4       00006413d8573cd20ed7128e53b7b13819fe5cfc2d801f...         91000002
# ...                                                   ...              ...
# 404434  4b9e8490036f8b6631c298802064fccd6c4ff41a5f755f...         91000002
# 404435  4b9eaaf9fc95c429580be86f3b51e8c603907927223823...         91000001
# 404436  4b9eae5f9fc8ebb4cdf45d0af977594dba73d7b97be909...         91000001
# 404437  4b9eb6a6ba2776d99ae241366b13b89a3bb0cbef20f0bc...         91000002
# 404438  4b9ec29639850ce7ec57ca9875cfc5a9d14f92a2c5f313...         91000002
#
# [404439 rows x 2 columns]

# %%
customer_bridge = customer_bridge.rename(columns={"fashion_news_id": "FN_id"})
customer_bridge
# Out:
#                                               customer_id     FN_id
# 0       00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...  91000001
# 1       0000423b00ade91418cceaf3b26c6af3dd342b51fd051e...  91000001
# 2       000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...  91000001
# 3       00005ca1c9ed5f5146b52ac8639a40ca9d57aeff4d1bd2...  91000001
# 4       00006413d8573cd20ed7128e53b7b13819fe5cfc2d801f...  91000002
# ...                                                   ...       ...
# 404434  4b9e8490036f8b6631c298802064fccd6c4ff41a5f755f...  91000002
# 404435  4b9eaaf9fc95c429580be86f3b51e8c603907927223823...  91000001
# 404436  4b9eae5f9fc8ebb4cdf45d0af977594dba73d7b97be909...  91000001
# 404437  4b9eb6a6ba2776d99ae241366b13b89a3bb0cbef20f0bc...  91000002
# 404438  4b9ec29639850ce7ec57ca9875cfc5a9d14f92a2c5f313...  91000002
#
# [404439 rows x 2 columns]

# %%
customer_bridge = customer_bridge.rename(columns={"FN_id": "fn_id"})
customer_bridge
# Out:
#                                               customer_id     fn_id
# 0       00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...  91000001
# 1       0000423b00ade91418cceaf3b26c6af3dd342b51fd051e...  91000001
# 2       000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...  91000001
# 3       00005ca1c9ed5f5146b52ac8639a40ca9d57aeff4d1bd2...  91000001
# 4       00006413d8573cd20ed7128e53b7b13819fe5cfc2d801f...  91000002
# ...                                                   ...       ...
# 404434  4b9e8490036f8b6631c298802064fccd6c4ff41a5f755f...  91000002
# 404435  4b9eaaf9fc95c429580be86f3b51e8c603907927223823...  91000001
# 404436  4b9eae5f9fc8ebb4cdf45d0af977594dba73d7b97be909...  91000001
# 404437  4b9eb6a6ba2776d99ae241366b13b89a3bb0cbef20f0bc...  91000002
# 404438  4b9ec29639850ce7ec57ca9875cfc5a9d14f92a2c5f313...  91000002
#
# [404439 rows x 2 columns]

# %%
article.to_csv(r'/Users/minahsu/Desktop/Columbia Work/Spring 2022/SQL/Group Project/tables/Python/Cleaned Table/article_bridge.csv', index = False)

# %%
color.to_csv(r'/Users/minahsu/Desktop/Columbia Work/Spring 2022/SQL/Group Project/tables/Python/Cleaned Table/color.csv', index = False)

# %%
customer_bridge.to_csv(r'/Users/minahsu/Desktop/Columbia Work/Spring 2022/SQL/Group Project/tables/Python/Cleaned Table/customer_bridge.csv', index = False)

# %%
department.to_csv(r'/Users/minahsu/Desktop/Columbia Work/Spring 2022/SQL/Group Project/tables/Python/Cleaned Table/department.csv', index = False)

# %%
fashion_news.to_csv(r'/Users/minahsu/Desktop/Columbia Work/Spring 2022/SQL/Group Project/tables/Python/Cleaned Table/fashion_news.csv', index = False)

# %%
graphical_appearance.to_csv(r'/Users/minahsu/Desktop/Columbia Work/Spring 2022/SQL/Group Project/tables/Python/Cleaned Table/graphical_appearance.csv', index = False)

# %%
index.to_csv(r'/Users/minahsu/Desktop/Columbia Work/Spring 2022/SQL/Group Project/tables/Python/Cleaned Table/index.csv', index = False)

# %%
section.to_csv(r'/Users/minahsu/Desktop/Columbia Work/Spring 2022/SQL/Group Project/tables/Python/Cleaned Table/section.csv', index = False)

# %%
trans.to_csv(r'/Users/minahsu/Desktop/Columbia Work/Spring 2022/SQL/Group Project/tables/Python/Cleaned Table/trans.csv', index = False)

# %%
product.to_csv(r'/Users/minahsu/Desktop/Columbia Work/Spring 2022/SQL/Group Project/tables/Python/Cleaned Table/product.csv', index = False)

# %%
customer_info.to_csv(r'/Users/minahsu/Desktop/Columbia Work/Spring 2022/SQL/Group Project/tables/Python/Cleaned Table/customer_info.csv', index = False)

# %%
#read data into postgresql
#!pip install sqlalchemy
from sqlalchemy import create_engine
import matplotlib.pyplot as plt

# %%
engine = create_engine("postgresql://postgres:123@localhost:5432/Group Project")
con = engine.connect()

# %%
color = pd.DataFrame(color)
color.to_sql(name='color',con=con,if_exists='append', index=False)

# %%
customer_info = pd.DataFrame(customer_info)
customer_info.to_sql(name='customer_info',con=con,if_exists='append', index=False)

# %%
department = pd.DataFrame(department)
department.to_sql(name='department',con=con,if_exists='append', index=False)

# %% [raw]
# fashion_news = pd.DataFrame(fashion_news)
# fashion_news.to_sql(name='fashion_news',con=con,if_exists='append', index=False)

# %%
graphical_appearance = pd.DataFrame(graphical_appearance)
graphical_appearance.to_sql(name='graphical_appearance',con=con,if_exists='append', index=False)

# %%
index = pd.DataFrame(index)
index.to_sql(name='index',con=con,if_exists='append', index=False)

# %%
product = pd.DataFrame(product)
product.to_sql(name='product',con=con,if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1750                 if not evt_handled:
# -> 1751                     self.dialect.do_executemany(
#    1752                         cursor, statement, parameters, context
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     961             xtras = self._psycopg2_extras()
# --> 962             context._psycopg2_fetched_rows = xtras.execute_values(
#     963                 cursor,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/psycopg2/extras.py in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1269         parts[-1:] = post
# ...

# %%
section = pd.DataFrame(section)
section.to_sql(name='section',con=con,if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1750                 if not evt_handled:
# -> 1751                     self.dialect.do_executemany(
#    1752                         cursor, statement, parameters, context
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     961             xtras = self._psycopg2_extras()
# --> 962             context._psycopg2_fetched_rows = xtras.execute_values(
#     963                 cursor,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/psycopg2/extras.py in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1269         parts[-1:] = post
# ...

# %%
cur.close()

# %%
#article,customer_bridge,trans have not insert
